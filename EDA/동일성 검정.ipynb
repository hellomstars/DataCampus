# %%
#!sudo apt-get install -y fonts-nanum
#!sudo fc-cache -fv
#!rm ~/.cache/matplotlib -rf

# %%
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rc('font', family='NanumBarunGothic') # For Windows
print(plt.rcParams['font.family'])
# Out:
# ['NanumBarunGothic']

# %%
# 수요를 충족한 자치구 모아두기
over = ['금천구', '서대문구', '마포구', '중구', '구로구', '송파구', '강남구', '광진구', '서초구', '양천구', '영등포구', '용산구', '은평구', '종로구']

# %% [markdown]
# ## 비만율 비교

# %%
# 비만율 데이터 가져온 후 다듬기
obesity = pd.read_excel('./rawdata/시·군·구별_비만율_자가보고__20220804005543.xlsx')
obesity = obesity.iloc[2:27,:].reset_index(drop = True)
obesity
# Out:
# C:\Users\Koo\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    시군구별(1) 시군구별(2) 시군구별(3)   2009 2009.1 2009.2 2009.3 2009.4   2010 2010.1  \
# 0      NaN     강남구      소계  916.0   19.6    1.4   20.5    1.3  914.0   16.3
# 1      NaN     강동구      소계  920.0   21.8    1.7   21.7    1.5  902.0   21.1
# 2      NaN     강북구      소계  919.0   23.4    1.4   23.1    1.6  889.0   22.1
# 3      NaN     강서구      소계  938.0   20.7    1.3   20.7    1.3  909.0   21.2
# 4      NaN     관악구      소계  900.0   22.2    1.7   22.4    1.4  928.0   20.5
# 5      NaN     광진구      소계  938.0   20.2    1.6   20.6    1.4  908.0   21.0
# 6      NaN     구로구      소계  896.0   25.4    1.6   24.7    1.5  895.0   21.3
# 7      NaN     금천구      소계  914.0   23.5    1.6   23.3    1.4  931.0   22.4
# 8      NaN     노원구      소계  922.0   20.1    1.4   19.9    1.4  906.0   25.1
# 9      NaN     도봉구      소계  920.0   21.5    1.5   21.7    1.5  903.0   26.6
# 10     NaN    동대문구      소계  918.0   20.0    1.7   19.9    1.4  911.0   22.7
# 11     NaN     동작구      소계  961.0   20.8    1.2   20.8    1.4  907.0   24.7
# 12     NaN     마포구      소계  905.0   19.9    1.3   19.9    1.3  889.0   23.0
# 13     NaN    서대문구      소계  947.0   19.8    1.4   19.7    1.3  913.0   22.6
# 14     NaN     서초구      소계  924.0   22.6    1.5   23.4    1.5  914.0   19.4
# 15     NaN     성동구      소계  918.0   22.7    1.6   22.7    1.3  897.0   21.6
# 16     NaN     성북구      소계  952.0   22.5    1.3   22.5    1.3  890.0   23.2
# 17     NaN     송파구      소계  928.0   20.1    1.3   20.6    1.2  919.0   17.9
# 18     NaN     양천구      소계  944.0   25.4    1.8   25.6    1.5  893.0   19.4
# 19     NaN    영등포구      소계  878.0   19.2    1.6   19.2    1.3  882.0   22.6
# 20     NaN     용산구      소계  919.0   19.5    1.2   19.1    1.2  897.0   17.7
# 21     NaN     은평구      소계  925.0   23.5    1.7   23.0    1.5  907.0   23.8
# 22     NaN     종로구      소계  952.0   21.1    1.1   20.6    1.2  913.0   22.7
# 23     NaN      중구      소계  925.0   23.5    1.4   22.9    1.4  911.0   19.7
# 24     NaN     중랑구      소계  973.0   18.2    1.3   18.3    1.3  911.0   26.6
#
#     ...   2018 2018.1 2018.2 2018.3 2018.4   2020 2020.1 2020.2 2020.3 2020.4
# 0   ...  906.0   23.8    1.3   24.1    1.3  909.0   24.8    1.4   26.3    1.3
# 1   ...  896.0   30.1    1.7   29.6    1.8  916.0   31.3    1.8   32.0    1.6
# 2   ...  838.0   28.5    1.9   29.3    1.7  904.0   30.3    1.7   31.2    2.0
# 3   ...  877.0   30.7    1.9   30.7    1.6  889.0   29.9    1.8   31.2    1.9
# 4   ...  906.0   26.2    1.4   26.1    1.7  917.0   26.6    1.6   25.5    1.5
# 5   ...  909.0   30.5    1.6   30.4    1.6  921.0   24.6    1.2   24.5    1.3
# 6   ...  897.0   31.3    1.7   30.3    1.6  907.0   29.0    1.5   28.7    1.7
# 7   ...  883.0   29.0    1.7   28.2    1.7  911.0   29.9    1.9   29.6    1.7
# 8   ...  901.0   30.2    1.4   30.4    1.6  903.0   30.9    1.6   31.7    1.7
# 9   ...  892.0   27.9    1.6   27.5    1.6  904.0   33.5    2.0   36.0    1.8
# 10  ...  915.0   30.3    1.7   29.4    1.6  916.0   30.8    1.7   30.5    1.6
# 11  ...  881.0   27.6    1.7   27.4    1.6  908.0   29.1    1.7   28.9    1.6
# 12  ...  898.0   26.6    1.7   25.6    1.5  899.0   27.2    1.6   27.7    1.6
# 13  ...  900.0   27.8    1.7   28.3    1.6  917.0   26.5    1.5   27.2    1.7
# 14  ...  896.0   23.8    1.5   24.1    1.5  905.0   24.0    1.4   24.7    1.5
# 15  ...  892.0   29.5    1.7   29.3    1.5  915.0   28.6    1.5   28.7    1.5
# 16  ...  905.0   32.3    1.8   32.2    1.7  908.0   27.5    1.8   27.0    1.6
# 17  ...  912.0   24.7    1.3   25.1    1.4  922.0   26.5    1.4   26.7    1.4
# 18  ...  883.0   29.5    1.9   29.1    1.7  898.0   28.6    1.5   28.9    1.6
# 19  ...  902.0   29.3    1.8   29.2    1.6  904.0   27.7    1.8   28.0    1.5
# 20  ...  878.0   24.7    1.4   24.0    1.6  840.0   25.4    1.6   24.6    1.8
# 21  ...  885.0   33.8    1.7   33.6    1.6  917.0   27.9    1.9   27.7    1.7
# 22  ...  868.0   32.4    1.7   32.5    1.9  895.0   28.1    1.5   28.9    1.5
# 23  ...  879.0   27.6    1.5   26.1    1.6  898.0   25.6    1.5   25.4    1.7
# 24  ...  894.0   34.2    1.9   34.1    1.9  905.0   31.4    1.8   31.8    1.7
#
# [25 rows x 58 columns]

# %%
# 2020년 비만율 데이터만 뽑아내기
obesity_raw = pd.DataFrame()
obesity_raw['지역'] = obesity['시군구별(2)']
obesity_raw['2020'] = obesity['2020.1']

obesity_raw
# Out:
#       지역  2020
# 0    강남구  24.8
# 1    강동구  31.3
# 2    강북구  30.3
# 3    강서구  29.9
# 4    관악구  26.6
# 5    광진구  24.6
# 6    구로구  29.0
# 7    금천구  29.9
# 8    노원구  30.9
# 9    도봉구  33.5
# 10  동대문구  30.8
# 11   동작구  29.1
# 12   마포구  27.2
# 13  서대문구  26.5
# 14   서초구  24.0
# 15   성동구  28.6
# 16   성북구  27.5
# 17   송파구  26.5
# 18   양천구  28.6
# 19  영등포구  27.7
# 20   용산구  25.4
# 21   은평구  27.9
# 22   종로구  28.1
# 23    중구  25.6
# 24   중랑구  31.4

# %%
# 수요를 충족한 자치구와 그렇지 못한 자치구로 데이터프레임 나누기
obesity_over = []
obesity_less = []
obesity_raw['수요'] = obesity_raw['지역'].copy()

for i in range(len(obesity_raw)):
  if obesity_raw['지역'][i] in over:
    obesity_raw['수요'][i] = '충족'
    obesity_over.append(obesity_raw.iloc[i,:])
  else:
    obesity_raw['수요'][i] = '부족'
    obesity_less.append(obesity_raw.iloc[i,:])

obesity_over = pd.DataFrame(obesity_over).reset_index(drop = True)
obesity_less = pd.DataFrame(obesity_less).reset_index(drop = True)

# %% [markdown]
# 분산 동일성 검정: p-value>0.1이므로 가설 채택

# %%
levene = stats.levene(obesity_over['2020'], obesity_less['2020'])
print("Obesity LeveneResult(statistic = %3.f, pvalue = %.3f)" % levene)
# Out:
# Obesity LeveneResult(statistic =   0, pvalue = 0.949)

# %% [markdown]
# 평균 동일성 검정: p-value<0.05이므로 평균이 동일하다는 가설 기각

# %%
obesity_ttest = stats.ttest_ind(obesity_over['2020'], obesity_less['2020'], equal_var = True)
print("Assuming equal variances(Obesity) : t-value = %.3f, p-value = %.3f)" % obesity_ttest)
# Out:
# Assuming equal variances(Obesity) : t-value = -4.194, p-value = 0.000)

# %% [markdown]
# #### box plot으로 시각화

# %%
plt.figure(figsize = (6, 6))
sns.boxplot(x = '수요', y = '2020', data = obesity_raw)
plt.title('비만율 비교')
plt.text(-0.47, 33.0, 'p-value: %.3f'% obesity_ttest[1], fontsize = 15)
plt.ylabel('비만율(%)')
plt.show()
# Out:
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52649 (\N{HANGUL SYLLABLE CUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51313 (\N{HANGUL SYLLABLE JOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### 다른 질병들에 대해서도 동일하게 진행

# %% [markdown]
# ## 고혈압 비교

# %%
blood = pd.read_excel('./rawdata/시·군·구별_고혈압_진단_경험률_30세_이상__20220818122116.xlsx')
blood = blood.iloc[2:27,:].reset_index(drop = True)
blood
# Out:
# C:\Users\Koo\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    시군구별(1) 시군구별(2) 시군구별(3)   2020 2020.1 2020.2 2020.3 2020.4
# 0      NaN     강남구      소계  749.0   19.9    1.5   17.3    1.2
# 1      NaN     강동구      소계  781.0   25.0    1.6   19.5    1.2
# 2      NaN     강북구      소계  791.0   30.5    1.8   22.6    1.4
# 3      NaN     강서구      소계  781.0   22.2    1.8   18.0    1.2
# 4      NaN     관악구      소계  699.0   24.7    1.7   18.8    1.2
# 5      NaN     광진구      소계  740.0   23.2    1.6   18.7    1.3
# 6      NaN     구로구      소계  777.0   23.9    1.7   18.8    1.2
# 7      NaN     금천구      소계  769.0   28.1    1.6   21.2    1.3
# 8      NaN     노원구      소계  790.0   27.9    2.0   20.8    1.2
# 9      NaN     도봉구      소계  760.0   26.5    1.6   20.5    1.4
# 10     NaN    동대문구      소계  785.0   27.1    2.2   19.5    1.2
# 11     NaN     동작구      소계  744.0   23.1    1.7   17.4    1.3
# 12     NaN     마포구      소계  738.0   25.2    1.4   21.2    1.4
# 13     NaN    서대문구      소계  766.0   27.9    1.9   21.3    1.3
# 14     NaN     서초구      소계  779.0   21.4    1.5   17.8    1.2
# 15     NaN     성동구      소계  731.0   22.0    1.5   18.5    1.2
# 16     NaN     성북구      소계  792.0   27.3    1.9   21.9    1.4
# 17     NaN     송파구      소계  784.0   20.4    1.2   16.6    1.1
# 18     NaN     양천구      소계  768.0   22.9    1.7   18.7    1.3
# 19     NaN    영등포구      소계  776.0   21.5    1.4   16.3    1.1
# 20     NaN     용산구      소계  781.0   29.1    1.6   21.7    1.5
# 21     NaN     은평구      소계  808.0   27.5    1.5   20.4    1.3
# 22     NaN     종로구      소계  767.0   24.0    1.2   17.1    1.1
# 23     NaN      중구      소계  760.0   21.2    1.6   15.6    1.2
# 24     NaN     중랑구      소계  768.0   26.6    1.6   19.9    1.4

# %%
blood_raw = pd.DataFrame()
blood_raw['지역'] = blood['시군구별(2)']
blood_raw['2020'] = blood['2020.1']

blood_raw
# Out:
#       지역  2020
# 0    강남구  19.9
# 1    강동구  25.0
# 2    강북구  30.5
# 3    강서구  22.2
# 4    관악구  24.7
# 5    광진구  23.2
# 6    구로구  23.9
# 7    금천구  28.1
# 8    노원구  27.9
# 9    도봉구  26.5
# 10  동대문구  27.1
# 11   동작구  23.1
# 12   마포구  25.2
# 13  서대문구  27.9
# 14   서초구  21.4
# 15   성동구  22.0
# 16   성북구  27.3
# 17   송파구  20.4
# 18   양천구  22.9
# 19  영등포구  21.5
# 20   용산구  29.1
# 21   은평구  27.5
# 22   종로구  24.0
# 23    중구  21.2
# 24   중랑구  26.6

# %%
blood_over = []
blood_less = []
blood_raw['수요'] = blood_raw['지역'].copy()

for i in range(len(blood_raw)):
  if blood_raw['지역'][i] in over:
    blood_raw['수요'][i] = '충족'
    blood_over.append(blood_raw.iloc[i,:])
  else:
    blood_raw['수요'][i] = '부족'
    blood_less.append(blood_raw.iloc[i,:])

blood_over = pd.DataFrame(blood_over).reset_index(drop = True)
blood_less = pd.DataFrame(blood_less).reset_index(drop = True)

# %%
levene = stats.levene(blood_over['2020'], blood_less['2020'])
print("Blood LeveneResult(statistic = %3.f, pvalue = %.3f)" % levene)
# Out:
# Blood LeveneResult(statistic =   0, pvalue = 0.497)

# %% [markdown]
# 분산 동일하다

# %%
blood_ttest = stats.ttest_ind(blood_over['2020'], blood_less['2020'], equal_var = True)
print("Assuming equal variances(Blood) : t-value = %.3f, p-value = %.3f)" % blood_ttest)
# Out:
# Assuming equal variances(Blood) : t-value = -1.463, p-value = 0.157)

# %% [markdown]
# 평균도 동일하다

# %% [markdown]
# #### 시각화

# %%
plt.figure(figsize = (6, 6))
sns.boxplot(x = '수요', y = '2020', data = blood_raw)
plt.text(-0.47, 30.0, 'p-value: %.3f'%blood_ttest[1], fontsize = 15)
plt.title('고혈압 비교')
plt.ylabel('고혈압(%)')
plt.show()
# Out:
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54792 (\N{HANGUL SYLLABLE HYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50517 (\N{HANGUL SYLLABLE AB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52649 (\N{HANGUL SYLLABLE CUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51313 (\N{HANGUL SYLLABLE JOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 당뇨병 비교

# %%
sugar = pd.read_excel('./rawdata/시·군·구별_당뇨병_진단_경험률_30세_이상__20220818122910.xlsx')
sugar = sugar.iloc[2:27,:].reset_index(drop = True)
sugar
# Out:
# C:\Users\Koo\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    시군구별(1) 시군구별(2) 시군구별(3)   2020 2020.1 2020.2 2020.3 2020.4
# 0      NaN     강남구      소계  749.0    7.5    1.0    6.3    0.8
# 1      NaN     강동구      소계  781.0   11.0    1.2    8.5    0.9
# 2      NaN     강북구      소계  792.0   14.0    1.2   10.2    0.9
# 3      NaN     강서구      소계  781.0    9.2    1.0    7.2    0.7
# 4      NaN     관악구      소계  699.0    9.0    0.9    7.2    0.8
# 5      NaN     광진구      소계  740.0   10.6    1.1    8.4    0.9
# 6      NaN     구로구      소계  777.0   10.6    1.1    8.3    0.9
# 7      NaN     금천구      소계  769.0   12.2    1.4    9.0    1.0
# 8      NaN     노원구      소계  790.0   11.7    1.4    8.5    0.9
# 9      NaN     도봉구      소계  760.0   13.0    1.3    9.7    1.0
# 10     NaN    동대문구      소계  785.0   10.9    1.1    8.0    0.9
# 11     NaN     동작구      소계  741.0   10.1    1.1    7.2    0.8
# 12     NaN     마포구      소계  738.0   11.4    1.1    9.3    0.9
# 13     NaN    서대문구      소계  766.0   10.2    1.0    7.6    0.9
# 14     NaN     서초구      소계  780.0    8.0    0.8    6.3    0.7
# 15     NaN     성동구      소계  731.0    9.4    1.2    7.8    0.9
# 16     NaN     성북구      소계  792.0   12.2    1.2    9.6    1.1
# 17     NaN     송파구      소계  784.0    8.6    1.0    7.0    0.8
# 18     NaN     양천구      소계  768.0    9.3    1.2    7.1    0.8
# 19     NaN    영등포구      소계  776.0    9.1    0.9    6.7    0.7
# 20     NaN     용산구      소계  781.0   10.3    1.0    7.1    0.8
# 21     NaN     은평구      소계  808.0    8.9    1.0    6.1    0.7
# 22     NaN     종로구      소계  767.0   12.1    1.4    8.6    1.0
# 23     NaN      중구      소계  760.0   11.2    1.4    8.0    0.9
# 24     NaN     중랑구      소계  768.0   14.0    1.4   11.3    1.2

# %%
sugar_raw = pd.DataFrame()
sugar_raw['지역'] = sugar['시군구별(2)']
sugar_raw['2020'] = sugar['2020.1']
sugar_raw
# Out:
#       지역  2020
# 0    강남구   7.5
# 1    강동구  11.0
# 2    강북구  14.0
# 3    강서구   9.2
# 4    관악구   9.0
# 5    광진구  10.6
# 6    구로구  10.6
# 7    금천구  12.2
# 8    노원구  11.7
# 9    도봉구  13.0
# 10  동대문구  10.9
# 11   동작구  10.1
# 12   마포구  11.4
# 13  서대문구  10.2
# 14   서초구   8.0
# 15   성동구   9.4
# 16   성북구  12.2
# 17   송파구   8.6
# 18   양천구   9.3
# 19  영등포구   9.1
# 20   용산구  10.3
# 21   은평구   8.9
# 22   종로구  12.1
# 23    중구  11.2
# 24   중랑구  14.0

# %%
sugar_over = []
sugar_less = []
sugar_raw['수요'] = sugar_raw['지역'].copy()

for i in range(len(sugar_raw)):
  if sugar_raw['지역'][i] in over:
    sugar_raw['수요'][i] = '충족'
    sugar_over.append(sugar_raw.iloc[i,:])
  else:
    sugar_raw['수요'][i] = '부족'
    sugar_less.append(sugar_raw.iloc[i,:])

sugar_over = pd.DataFrame(sugar_over).reset_index(drop = True)
sugar_less = pd.DataFrame(sugar_less).reset_index(drop = True)

# %%
levene = stats.levene(sugar_over['2020'], sugar_less['2020'])
print("Sugar LeveneResult(statistic = %3.f, pvalue = %.3f)" % levene)
# Out:
# Sugar LeveneResult(statistic =   1, pvalue = 0.453)

# %% [markdown]
# 분산 동일하다

# %%
sugar_ttest = stats.ttest_ind(sugar_over['2020'], sugar_less['2020'], equal_var = True)
print("Assuming equal variances(Sugar) : (t-value = %.3f, p-value = %.3f)" % sugar_ttest)
# Out:
# Assuming equal variances(Sugar) : (t-value = -1.998, p-value = 0.058)

# %% [markdown]
# 평균은 동일하다..? 살짝 애매

# %% [markdown]
# #### 시각화

# %%
plt.figure(figsize = (6, 6))
sns.boxplot(x = '수요', y = '2020', data = sugar_raw)
plt.text(-0.47, 13.6, 'p-value: %.3f'%sugar_ttest[1], fontsize = 15)
plt.title('당뇨병 비교')
plt.ylabel('당뇨병(%)')
plt.show()
# Out:
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45544 (\N{HANGUL SYLLABLE NYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48337 (\N{HANGUL SYLLABLE BYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52649 (\N{HANGUL SYLLABLE CUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51313 (\N{HANGUL SYLLABLE JOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # 대사 위험군 보유현황

# %%
danger = pd.read_excel('./rawdata/시군구별_성별_대사증후군_위험요인별_현황_20220818125532.xlsx')
danger = danger.iloc[5:83,:].dropna(subset = ['시군구별(2)']).drop(['시군구별(1)', '성별(1)'], axis = 1).reset_index(drop = True)
danger
# Out:
# C:\Users\Koo\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    시군구별(2)       2020    2020.1 2020.2     2020.3 2020.4    2020.5 2020.6  \
# 0       소계  2507172.0  634997.0   25.3  1084873.0   43.3  992080.0   39.6
# 1      종로구    36223.0    9347.0   25.8    15171.0   41.9   14726.0   40.7
# 2       중구    32363.0    7731.0   23.9    13869.0   42.9   12929.0   39.9
# 3      용산구    51931.0   12661.0   24.4    21056.0   40.5   20895.0   40.2
# 4      성동구    76186.0   18913.0   24.8    31793.0   41.7   28584.0   37.5
# 5      광진구    92372.0   22995.0   24.9    38590.0   41.8   33974.0   36.8
# 6     동대문구    87695.0   25463.0   29.0    40644.0   46.3   34685.0   39.6
# 7      중랑구   102587.0   28683.0   28.0    50061.0   48.8   45312.0   44.2
# 8      성북구   111445.0   30244.0   27.1    51030.0   45.8   45530.0   40.9
# 9      강북구    78423.0   21999.0   28.1    40355.0   51.5   34514.0   44.0
# 10     도봉구    87255.0   24155.0   27.7    43023.0   49.3   38554.0   44.2
# 11     노원구   136700.0   35267.0   25.8    62224.0   45.5   52812.0   38.6
# 12     은평구   123464.0   32489.0   26.3    56721.0   45.9   53510.0   43.3
# 13    서대문구    79056.0   19947.0   25.2    33314.0   42.1   32733.0   41.4
# 14     마포구    93203.0   21798.0   23.4    36374.0   39.0   36893.0   39.6
# 15     양천구   115713.0   30489.0   26.3    50754.0   43.9   44413.0   38.4
# 16     강서구   169063.0   44637.0   26.4    71079.0   42.0   65505.0   38.7
# 17     구로구   115817.0   30846.0   26.6    53320.0   46.0   49492.0   42.7
# 18     금천구    68591.0   19043.0   27.8    32194.0   46.9   28847.0   42.1
# 19    영등포구   105404.0   26536.0   25.2    43813.0   41.6   42204.0   40.0
# 20     동작구   103293.0   24253.0   23.5    42604.0   41.2   39379.0   38.1
# 21     관악구   133161.0   33290.0   25.0    57154.0   42.9   51616.0   38.8
# 22     서초구    97585.0   20733.0   21.2    35749.0   36.6   35058.0   35.9
# 23     강남구   120771.0   25409.0   21.0    43252.0   35.8   43423.0   36.0
# 24     송파구   174846.0   39675.0   22.7    69386.0   39.7   62451.0   35.7
# 25     강동구   114025.0   28394.0   24.9    51343.0   45.0   44041.0   38.6
#
#       2020.7 2020.8    2020.9 2020.10
# 0   433316.0   17.3  157172.0     6.3
# 1     6014.0   16.6    2332.0     6.4
# 2     5671.0   17.5    2135.0     6.6
# 3     8306.0   16.0    2525.0     4.9
# 4    12842.0   16.9    4640.0     6.1
# 5    14886.0   16.1    5334.0     5.8
# 6    15222.0   17.4    6045.0     6.9
# 7    18783.0   18.3    6562.0     6.4
# 8    20006.0   18.0    7507.0     6.7
# 9    15666.0   20.0    6000.0     7.7
# 10   17733.0   20.3    6313.0     7.2
# 11   25564.0   18.7    8174.0     6.0
# 12   24040.0   19.5    7780.0     6.3
# 13   14437.0   18.3    5208.0     6.6
# 14   15348.0   16.5    5397.0     5.8
# 15   20153.0   17.4    7960.0     6.9
# 16   28930.0   17.1   11035.0     6.5
# 17   21228.0   18.3    8255.0     7.1
# 18   11811.0   17.2    4502.0     6.6
# 19   17313.0   16.4    6575.0     6.2
# 20   17176.0   16.6    5920.0     5.7
# 21   20772.0   15.6    7714.0     5.8
# 22   15066.0   15.4    5036.0     5.2
# 23   18573.0   15.4    6512.0     5.4
# 24   27590.0   15.8   10437.0     6.0
# 25   20186.0   17.7    7274.0     6.4

# %% [markdown]
# ### 복부비만

# %%
danger_1 = pd.DataFrame(columns = ['지역', '복부비만'])
danger_1['지역'] = danger['시군구별(2)']
danger_1['복부비만'] = danger['2020.2']
danger_1 = danger_1.drop(0, axis = 0).reset_index(drop = True)
danger_1
# Out:
#       지역  복부비만
# 0    종로구  25.8
# 1     중구  23.9
# 2    용산구  24.4
# 3    성동구  24.8
# 4    광진구  24.9
# 5   동대문구  29.0
# 6    중랑구  28.0
# 7    성북구  27.1
# 8    강북구  28.1
# 9    도봉구  27.7
# 10   노원구  25.8
# 11   은평구  26.3
# 12  서대문구  25.2
# 13   마포구  23.4
# 14   양천구  26.3
# 15   강서구  26.4
# 16   구로구  26.6
# 17   금천구  27.8
# 18  영등포구  25.2
# 19   동작구  23.5
# 20   관악구  25.0
# 21   서초구  21.2
# 22   강남구  21.0
# 23   송파구  22.7
# 24   강동구  24.9

# %%
danger_1_over = []
danger_1_less = []
danger_1['수요'] = danger_1['지역'].copy()

for i in range(len(danger_1)):
  if danger_1['지역'][i] in over:
    danger_1['수요'][i] = '충족'
    danger_1_over.append(danger_1.iloc[i,:])
  else:
    danger_1['수요'][i] = '부족'
    danger_1_less.append(danger_1.iloc[i,:])

danger_1_over = pd.DataFrame(danger_1_over).reset_index(drop = True)
danger_1_less = pd.DataFrame(danger_1_less).reset_index(drop = True)

# %%
levene = stats.levene(danger_1_over['복부비만'], danger_1_less['복부비만'])
print("LeveneResult(statistic = %3.f, pvalue = %.3f)" % levene)
# Out:
# LeveneResult(statistic =   0, pvalue = 0.817)

# %% [markdown]
# 분산 동일하다

# %%
danger_1_ttest = stats.ttest_ind(danger_1_over['복부비만'], danger_1_less['복부비만'], equal_var = True)
print("Assuming equal variances(복부비만) : (t-value = %.3f, p-value = %.3f)" % danger_1_ttest)
# Out:
# Assuming equal variances(복부비만) : (t-value = -2.322, p-value = 0.029)

# %% [markdown]
# 평균 유의하게 다르다

# %% [markdown]
# #### 시각화

# %%
plt.figure(figsize = (6, 6))
sns.boxplot(x = '수요', y = '복부비만', data = danger_1)
plt.text(-0.47, 29.0, 'p-value: %.3f'% danger_1_ttest[1], fontsize = 15)
plt.title('복부비만 비교')
plt.ylabel('복부비만(%)')
plt.show()
# Out:
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48373 (\N{HANGUL SYLLABLE BOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52649 (\N{HANGUL SYLLABLE CUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51313 (\N{HANGUL SYLLABLE JOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### 높은 혈압

# %%
danger_2 = pd.DataFrame(columns = ['지역', '높은혈압'])
danger_2['지역'] = danger['시군구별(2)']
danger_2['높은혈압'] = danger['2020.4']
danger_2 = danger_2.drop(0, axis = 0).reset_index(drop = True)
danger_2
# Out:
#       지역  높은혈압
# 0    종로구  41.9
# 1     중구  42.9
# 2    용산구  40.5
# 3    성동구  41.7
# 4    광진구  41.8
# 5   동대문구  46.3
# 6    중랑구  48.8
# 7    성북구  45.8
# 8    강북구  51.5
# 9    도봉구  49.3
# 10   노원구  45.5
# 11   은평구  45.9
# 12  서대문구  42.1
# 13   마포구  39.0
# 14   양천구  43.9
# 15   강서구  42.0
# 16   구로구  46.0
# 17   금천구  46.9
# 18  영등포구  41.6
# 19   동작구  41.2
# 20   관악구  42.9
# 21   서초구  36.6
# 22   강남구  35.8
# 23   송파구  39.7
# 24   강동구  45.0

# %%
danger_2_over = []
danger_2_less = []
danger_2['수요'] = danger_2['지역'].copy()

for i in range(len(danger_2)):
  if danger_2['지역'][i] in over:
    danger_2['수요'][i] = '충족'
    danger_2_over.append(danger_2.iloc[i,:])
  else:
    danger_2['수요'][i] = '부족'
    danger_2_less.append(danger_2.iloc[i,:])

danger_2_over = pd.DataFrame(danger_2_over).reset_index(drop = True)
danger_2_less = pd.DataFrame(danger_2_less).reset_index(drop = True)

# %%
levene = stats.levene(danger_2_over['높은혈압'], danger_2_less['높은혈압'])
print("LeveneResult(statistic = %3.f, pvalue = %.3f)" % levene)
# Out:
# LeveneResult(statistic =   0, pvalue = 0.852)

# %% [markdown]
# 분산 동일하다

# %%
danger_2_ttest = stats.ttest_ind(danger_2_over['높은혈압'], danger_2_less['높은혈압'], equal_var = True)
print("Assuming equal variances(높은혈압) : (t-value = %.3f, p-value = %.3f)" % danger_2_ttest)
# Out:
# Assuming equal variances(높은혈압) : (t-value = -2.743, p-value = 0.012)

# %% [markdown]
# 평균 유의하게 차이 있다

# %% [markdown]
# #### 시각화

# %%
plt.figure(figsize = (6, 6))
sns.boxplot(x = '수요', y = '높은혈압', data = danger_2)
plt.text(-0.47, 51.0, 'p-value: %.3f'% danger_2_ttest[1], fontsize = 15)
plt.title('높은혈압 비교')
plt.ylabel('높은혈압(%)')
plt.show()
# Out:
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45458 (\N{HANGUL SYLLABLE NOP}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54792 (\N{HANGUL SYLLABLE HYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50517 (\N{HANGUL SYLLABLE AB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52649 (\N{HANGUL SYLLABLE CUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51313 (\N{HANGUL SYLLABLE JOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### 높은 혈당

# %%
danger_3 = pd.DataFrame(columns = ['지역', '높은혈당'])
danger_3['지역'] = danger['시군구별(2)']
danger_3['높은혈당'] = danger['2020.6']
danger_3 = danger_3.drop(0, axis = 0).reset_index(drop = True)
danger_3
# Out:
#       지역  높은혈당
# 0    종로구  40.7
# 1     중구  39.9
# 2    용산구  40.2
# 3    성동구  37.5
# 4    광진구  36.8
# 5   동대문구  39.6
# 6    중랑구  44.2
# 7    성북구  40.9
# 8    강북구  44.0
# 9    도봉구  44.2
# 10   노원구  38.6
# 11   은평구  43.3
# 12  서대문구  41.4
# 13   마포구  39.6
# 14   양천구  38.4
# 15   강서구  38.7
# 16   구로구  42.7
# 17   금천구  42.1
# 18  영등포구  40.0
# 19   동작구  38.1
# 20   관악구  38.8
# 21   서초구  35.9
# 22   강남구  36.0
# 23   송파구  35.7
# 24   강동구  38.6

# %%
danger_3_over = []
danger_3_less = []
danger_3['수요'] = danger_3['지역'].copy()

for i in range(len(danger_3)):
  if danger_3['지역'][i] in over:
    danger_3['수요'][i] = '충족'
    danger_3_over.append(danger_3.iloc[i,:])
  else:
    danger_3['수요'][i] = '부족'
    danger_3_less.append(danger_3.iloc[i,:])

danger_3_over = pd.DataFrame(danger_3_over).reset_index(drop = True)
danger_3_less = pd.DataFrame(danger_3_less).reset_index(drop = True)

# %%
levene = stats.levene(danger_3_over['높은혈당'], danger_3_less['높은혈당'])
print("LeveneResult(statistic = %3.f, pvalue = %.3f)" % levene)
# Out:
# LeveneResult(statistic =   0, pvalue = 0.937)

# %% [markdown]
# 분산 동일하다

# %%
danger_3_ttest = stats.ttest_ind(danger_3_over['높은혈당'], danger_3_less['높은혈당'], equal_var = True)
print("Assuming equal variances(높은혈당) : (t-value = %.3f, p-value = %.3f)" % danger_3_ttest)
# Out:
# Assuming equal variances(높은혈당) : (t-value = -0.780, p-value = 0.443)

# %% [markdown]
# 유의한 차이가 없다

# %% [markdown]
# #### 시각화

# %%
plt.figure(figsize = (6, 6))
sns.boxplot(x = '수요', y = '높은혈당', data = danger_3)
plt.text(-0.47, 44.0, 'p-value: %.3f'% danger_3_ttest[1], fontsize = 15)
plt.title('높은혈당 비교')
plt.ylabel('높은혈당(%)')
plt.show()
# Out:
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45458 (\N{HANGUL SYLLABLE NOP}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54792 (\N{HANGUL SYLLABLE HYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52649 (\N{HANGUL SYLLABLE CUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51313 (\N{HANGUL SYLLABLE JOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### 고중성지방혈증

# %%
danger_4 = pd.DataFrame(columns = ['지역', '고중성지방혈증'])
danger_4['지역'] = danger['시군구별(2)']
danger_4['고중성지방혈증'] = danger['2020.8']
danger_4 = danger_4.drop(0, axis = 0).reset_index(drop = True)
danger_4
# Out:
#       지역 고중성지방혈증
# 0    종로구    16.6
# 1     중구    17.5
# 2    용산구    16.0
# 3    성동구    16.9
# 4    광진구    16.1
# 5   동대문구    17.4
# 6    중랑구    18.3
# 7    성북구    18.0
# 8    강북구    20.0
# 9    도봉구    20.3
# 10   노원구    18.7
# 11   은평구    19.5
# 12  서대문구    18.3
# 13   마포구    16.5
# 14   양천구    17.4
# 15   강서구    17.1
# 16   구로구    18.3
# 17   금천구    17.2
# 18  영등포구    16.4
# 19   동작구    16.6
# 20   관악구    15.6
# 21   서초구    15.4
# 22   강남구    15.4
# 23   송파구    15.8
# 24   강동구    17.7

# %%
danger_4_over = []
danger_4_less = []
danger_4['수요'] = danger_4['지역'].copy()

for i in range(len(danger_4)):
  if danger_4['지역'][i] in over:
    danger_4['수요'][i] = '충족'
    danger_4_over.append(danger_4.iloc[i,:])
  else:
    danger_4['수요'][i] = '부족'
    danger_4_less.append(danger_4.iloc[i,:])

danger_4_over = pd.DataFrame(danger_4_over).reset_index(drop = True)
danger_4_less = pd.DataFrame(danger_4_less).reset_index(drop = True)

# %%
levene = stats.levene(danger_4_over['고중성지방혈증'], danger_4_less['고중성지방혈증'])
print("LeveneResult(statistic = %3.f, pvalue = %.3f)" % levene)
# Out:
# LeveneResult(statistic =   0, pvalue = 0.722)

# %% [markdown]
# 분산 동일하다

# %%
danger_4_ttest = stats.ttest_ind(danger_4_over['고중성지방혈증'], danger_4_less['고중성지방혈증'], equal_var = True)
print("Assuming equal variances(고중성지방혈증) : (t-value = %.4f, p-value = %.4f)" % danger_4_ttest)
# Out:
# Assuming equal variances(고중성지방혈증) : (t-value = -1.8832, p-value = 0.0724)

# %% [markdown]
# 큰 차이를 보이지 않는다

# %% [markdown]
# #### 시각화

# %%
plt.figure(figsize = (6, 6))
sns.boxplot(x = '수요', y = '고중성지방혈증', data = danger_4)
plt.text(-0.47, 20.0, 'p-value: %.3f'% danger_4_ttest[1], fontsize = 15)
plt.title('고중성지방혈증 비교')
plt.ylabel('고중성지방혈증(%)')
plt.show()
# Out:
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48169 (\N{HANGUL SYLLABLE BANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54792 (\N{HANGUL SYLLABLE HYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51613 (\N{HANGUL SYLLABLE JEUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52649 (\N{HANGUL SYLLABLE CUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51313 (\N{HANGUL SYLLABLE JOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### 낮은 HDL 콜레스테롤 혈증

# %%
danger_5 = pd.DataFrame(columns = ['지역', '낮은 HDL 콜레스테롤 혈증'])
danger_5['지역'] = danger['시군구별(2)']
danger_5['낮은 HDL 콜레스테롤 혈증'] = danger['2020.10']
danger_5 = danger_5.drop(0, axis = 0).reset_index(drop = True)
danger_5
# Out:
#       지역 낮은 HDL 콜레스테롤 혈증
# 0    종로구             6.4
# 1     중구             6.6
# 2    용산구             4.9
# 3    성동구             6.1
# 4    광진구             5.8
# 5   동대문구             6.9
# 6    중랑구             6.4
# 7    성북구             6.7
# 8    강북구             7.7
# 9    도봉구             7.2
# 10   노원구             6.0
# 11   은평구             6.3
# 12  서대문구             6.6
# 13   마포구             5.8
# 14   양천구             6.9
# 15   강서구             6.5
# 16   구로구             7.1
# 17   금천구             6.6
# 18  영등포구             6.2
# 19   동작구             5.7
# 20   관악구             5.8
# 21   서초구             5.2
# 22   강남구             5.4
# 23   송파구             6.0
# 24   강동구             6.4

# %%
danger_5_over = []
danger_5_less = []
danger_5['수요'] = danger_5['지역'].copy()

for i in range(len(danger_5)):
  if danger_5['지역'][i] in over:
    danger_5['수요'][i] = '충족'
    danger_5_over.append(danger_5.iloc[i,:])
  else:
    danger_5['수요'][i] = '부족'
    danger_5_less.append(danger_5.iloc[i,:])

danger_5_over = pd.DataFrame(danger_5_over).reset_index(drop = True)
danger_5_less = pd.DataFrame(danger_5_less).reset_index(drop = True)

# %%
levene = stats.levene(danger_5_over['낮은 HDL 콜레스테롤 혈증'], danger_5_less['낮은 HDL 콜레스테롤 혈증'])
print("LeveneResult(statistic = %3.f, pvalue = %.3f)" % levene)
# Out:
# LeveneResult(statistic =   0, pvalue = 0.706)

# %% [markdown]
# 분산 동일하다

# %%
danger_5_ttest = stats.ttest_ind(danger_5_over['낮은 HDL 콜레스테롤 혈증'], danger_5_less['낮은 HDL 콜레스테롤 혈증'], equal_var = True)
print("Assuming equal variances(낮은 HDL 콜레스테롤 혈증) : (t-value = %.4f, p-value = %.4f)" % danger_5_ttest)
# Out:
# Assuming equal variances(낮은 HDL 콜레스테롤 혈증) : (t-value = -1.4268, p-value = 0.1671)

# %% [markdown]
# 평균은 큰 차이를 보이지 않는다

# %% [markdown]
# #### 시각화

# %%
plt.figure(figsize = (6, 6))
sns.boxplot(x = '수요', y = '낮은 HDL 콜레스테롤 혈증', data = danger_5)
plt.text(-0.47, 7.5, 'p-value: %.3f'% danger_5_ttest[1], fontsize = 15)
plt.title('낮은 HDL 콜레스테롤 혈증 비교')
plt.ylabel('낮은 HDL 콜레스테롤 혈증(%)')
plt.show()
# Out:
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45230 (\N{HANGUL SYLLABLE NAJ}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 53084 (\N{HANGUL SYLLABLE KOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47112 (\N{HANGUL SYLLABLE RE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 53580 (\N{HANGUL SYLLABLE TE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47204 (\N{HANGUL SYLLABLE ROL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54792 (\N{HANGUL SYLLABLE HYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51613 (\N{HANGUL SYLLABLE JEUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52649 (\N{HANGUL SYLLABLE CUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51313 (\N{HANGUL SYLLABLE JOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Koo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
